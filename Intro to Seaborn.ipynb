# %%
import matplotlib.pyplot as plt

# %%
x=[10,20,30,40]
y=[0,15,10,25]
plt.plot(x,y)

# %%
import seaborn as sns

# %%
sns.set()

# %%
plt.plot(x,y)

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
cars=sns.load_dataset('mpg')
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.dropna(inplace=True)
cars.shape
# Out:
# (392, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(x='model_year',y='mpg',col='origin',hue='cylinders',data=cars)

# %% [markdown]
# ### Univariate (1D)

# %%
sns.kdeplot(cars.horsepower)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower,shade=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower,cumulative=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %% [markdown]
# ### Bivariate(2D)

# %%
sns.kdeplot(cars.horsepower,cars.mpg)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.kdeplot(cars.horsepower,cars.mpg,n_levels=20)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.kdeplot(cars.horsepower,cars.mpg,shade=True,shade_lowest=False)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:1676: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.kdeplot(cars.horsepower,cars.mpg,shade=True,cbar=True)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.distplot(cars.weight)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(cars.weight,kde=False)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight'>

# %%
sns.distplot(cars.weight,hist=False)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(cars.weight,rug=True)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(cars.weight,bins=10)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(cars.weight,bins=[1500,1700,2000,2200])
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
from scipy.stats import norm
sns.distplot(cars.weight,fit=norm)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
from scipy.stats import skewnorm
sns.distplot(cars.weight,fit=skewnorm,kde=False)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight'>

# %%
sns.distplot(cars.weight,kde=False,hist_kws={'alpha':1,'histtype':'step'})
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight'>

# %%
sns.distplot(cars.weight,kde=False,hist_kws={'alpha':1,'histtype':'stepfilled'})
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight'>

# %%
sns.distplot(cars.weight,kde_kws={'lw':5})
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(cars.weight,rug=True,rug_kws={'height':0.20})
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(cars.weight,rug=True,color='r',rug_kws={'height':0.20})
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(cars.weight,rug=True,rug_kws={'height':0.20,'color':'r'})
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.boxplot(cars.mpg)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg'>

# %%
cars.mpg.describe()
# Out:
# count    392.000000
# mean      23.445918
# std        7.805007
# min        9.000000
# 25%       17.000000
# 50%       22.750000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
sns.boxplot(x=cars.origin,y=cars.mpg)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',data=cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',data=cars,hue='cylinders')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
cars.model_year.describe()
# Out:
# count    392.000000
# mean      75.979592
# std        3.683737
# min       70.000000
# 25%       73.000000
# 50%       76.000000
# 75%       79.000000
# max       82.000000
# Name: model_year, dtype: float64

# %%
cars['newer']=cars.model_year>76

# %%
sns.boxplot(x='origin',y='mpg',data=cars,hue='newer')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',data=cars,hue='newer',color='g')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',data=cars,hue='newer',linewidth=2)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',data=cars,hue='newer',linewidth=2,whis=2)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',data=cars,hue='newer',linewidth=2,showcaps=False)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
cars=cars[cars.cylinders.isin([4,6,8])]

# %%
sns.violinplot(cars.displacement)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='displacement'>

# %%
sns.violinplot(y=cars.displacement,x=cars.cylinders)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(y=cars.displacement,x=cars.cylinders,
               hue=cars.origin,data=cars)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(y='displacement',x='cylinders',
               hue='origin',
               data=cars[cars.origin.isin(['japan','europe'])])
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(y='displacement',x='cylinders',
               hue='origin',split=True,
               data=cars[cars.origin.isin(['japan','europe'])])
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(y='displacement',x='cylinders',
               hue='origin',split=True,
               inner='quartiles',
               data=cars[cars.origin.isin(['japan','europe'])])
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(y='displacement',x='cylinders',
               hue='origin',split=True
               ,scale='count',inner='quartiles'
               ,data=cars[cars.origin.isin(['japan','europe'])])
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(y='displacement',x='cylinders',
               hue='origin',split=True
               ,scale='count',inner='quartiles',scale_hue=False
               ,data=cars[cars.origin.isin(['japan','europe'])])
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
cars[cars.origin.isin(['japan','europe'])].groupby('cylinders').origin.value_counts()
# Out:
# cylinders  origin
# 4          japan     69
#            europe    61
# 6          japan      6
#            europe     4
# Name: origin, dtype: int64

# %%
diamonds=sns.load_dataset('diamonds')
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds=diamonds[
    diamonds.cut.isin(['Premium','Good']) & 
    diamonds.color.isin(['D','F','J'])].sample(n=100,random_state=22)
diamonds.shape
# Out:
# (100, 10)

# %%
sns.scatterplot(diamonds.carat,diamonds.price)
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='x',y='y',data=diamonds)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.scatterplot(x='x',y='y',data=diamonds,hue='cut')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.scatterplot(x='x',y='y',data=diamonds,hue='depth')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.scatterplot(x='carat',y='price',style='cut',data=diamonds,s=100)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',size='cut',data=diamonds,s=100)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',size='depth',data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',hue='cut',style='cut',s=100,data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',hue='cut',style='color',s=100,data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',s=100,data=diamonds,alpha=0.6)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',hue='cut',style='cut',s=100,data=diamonds,marker='*',edgecolor='black')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
origin_cyl=(cars.groupby('origin').cylinders.value_counts().unstack().fillna(0))

# %%
sns.heatmap(origin_cyl)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
import numpy as np
test_array=np.array([[1,5],[3,8]])
sns.heatmap(test_array)
# Out:
# <AxesSubplot:>

# %%
origin_cyl.T
# Out:
# origin     europe  japan    usa
# cylinders
# 4            61.0   69.0   69.0
# 6             4.0    6.0   73.0
# 8             0.0    0.0  103.0

# %%
sns.heatmap(origin_cyl.T)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='cylinders'>

# %%
cars.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.794872     -0.817887   -0.780259 -0.842681
# cylinders    -0.794872   1.000000      0.950701    0.851037  0.900707
# displacement -0.817887   0.950701      1.000000    0.902830  0.935296
# horsepower   -0.780259   0.851037      0.902830    1.000000  0.868906
# weight       -0.842681   0.900707      0.935296    0.868906  1.000000
# acceleration  0.419337  -0.525945     -0.560622   -0.692051 -0.431067
# model_year    0.579778  -0.352061     -0.373971   -0.416865 -0.315424
# newer         0.522342  -0.275645     -0.296957   -0.310069 -0.275993
#
#               acceleration  model_year     newer
# mpg               0.419337    0.579778  0.522342
# cylinders        -0.525945   -0.352061 -0.275645
# displacement     -0.560622   -0.373971 -0.296957
# horsepower       -0.692051   -0.416865 -0.310069
# weight           -0.431067   -0.315424 -0.275993
# ...

# %%
sns.heatmap(cars.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),cmap='RdBu',center=0)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),cmap='RdBu',center=0,annot=True,fmt='.3f')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),cmap='RdBu',center=0,annot=True,fmt='.3f'
           ,annot_kws={
               'fontweight':'bold',
               'fontfamily':'serif'
           })
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),cmap='RdBu',center=0,annot=True,fmt='.3f',linewidth='1',linecolor='black')
# Out:
# <AxesSubplot:>

# %%
labels=['MPG','Cylinders','Displacement','Horsepower','Weight','Acceleration','Model Year']
sns.heatmap(cars.corr(),cmap='RdBu',center=0,annot=True,fmt='.3f',
           xticklabels=labels,yticklabels=labels)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),cmap='RdBu',center=0,annot=True,fmt='.3f',
           xticklabels=False,yticklabels=labels)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),cmap='RdBu',center=0,annot=True,fmt='.3f',
           xticklabels=labels,yticklabels=labels,square=True)
# Out:
# <AxesSubplot:>

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips)

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.pairplot(tips,kind='reg')

# %%
sns.pairplot(tips,kind='bar')

# %%
g=sns.pairplot(tips)

# %%
type(g)
# Out:
# seaborn.axisgrid.PairGrid

# %%
g=sns.pairplot(tips)
g.map_upper(sns.kdeplot,n_levels=6,color='xkcd:wine red')

# %%
tips['weekend']=tips.day.isin(['Sat','Sun'])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  weekend
# 0       16.99  1.01  Female     No  Sun  Dinner     2     True
# 1       10.34  1.66    Male     No  Sun  Dinner     3     True
# 2       21.01  3.50    Male     No  Sun  Dinner     3     True
# 3       23.68  3.31    Male     No  Sun  Dinner     2     True
# 4       24.59  3.61  Female     No  Sun  Dinner     4     True

# %%
sns.pairplot(tips,hue='weekend')

# %%
sns.pairplot(tips,
             hue='weekend',
             y_vars=['tip'],
             x_vars=['total_bill','size'],
             kind='reg',
             height=4
            )

# %%
from ipywidgets import interactive
def size_widget(height=2.5,aspect=1):
    sns.pairplot(tips,height=height,aspect=aspect)

# %%
interactive(size_widget,height=(1,3.5,0.5),aspect=(0.5,2,0.25))
# Out:
# interactive(children=(FloatSlider(value=2.5, description='height', max=3.5, min=1.0, step=0.5), FloatSlider(va…

# %%
sns.pairplot(tips,hue='day',palette='plasma')
# Out:
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Chirubhai\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(tips,diag_kws={'color':'gray','alpha':0.6})
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.pairplot(tips,kind='reg',plot_kws={'color':'gray'})
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
pen=sns.load_dataset('penguins')

# %%
pen.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.barplot(x='species',y='body_mass_g',data=pen)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
pen.groupby('species').body_mass_g.mean()
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %%
sns.barplot(x='body_mass_g',y='species',data=pen)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
sns.barplot(x='body_mass_g',y='species',data=pen,
           estimator=np.std)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
pen.groupby('species').body_mass_g.describe()
# Out:
#            count         mean         std     min     25%     50%     75%  \
# species
# Adelie     151.0  3700.662252  458.566126  2850.0  3350.0  3700.0  4000.0
# Chinstrap   68.0  3733.088235  384.335081  2700.0  3487.5  3700.0  3950.0
# Gentoo     123.0  5076.016260  504.116237  3950.0  4700.0  5000.0  5500.0
#
#               max
# species
# Adelie     4775.0
# Chinstrap  4800.0
# Gentoo     6300.0

# %%
sns.barplot(x='body_mass_g',y='species',data=pen,
           estimator=np.max)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
sns.barplot(x='body_mass_g',y='species',data=pen,
           estimator=np.min)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
sns.barplot(x='body_mass_g',y='species',data=pen,hue='sex')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
sns.barplot(x='body_mass_g',y='species',data=pen,order=['Gentoo','Chinstrap','Adelie'])
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
sns.barplot(x='body_mass_g',y='species',data=pen,color='g')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
sns.barplot(x='body_mass_g',y='species',data=pen,color='g',
            errcolor='darkslateblue',errwidth=9)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
sns.barplot(x='body_mass_g',y='species',data=pen,palette='hot')
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
diamonds=diamonds[diamonds.clarity.isin(['ST1','VS2'])]

# %%
sns.countplot(x='color',data=diamonds)
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>
